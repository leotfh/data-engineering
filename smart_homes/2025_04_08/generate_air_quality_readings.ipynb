# %%
import os
import random
import time
from datetime import datetime
import xml.etree.ElementTree as ET
from xml.dom import minidom
import pandas as pd
from sklearn.linear_model import LinearRegression

# Create output directory
output_dir = "sensor_data/xml"
os.makedirs(output_dir, exist_ok=True)

def classify_health_environment(pm2_5, pm10, so2, no2):
    score = 0
    if pm2_5 > 100: score += 1
    if pm10 > 150: score += 1
    if so2 > 100: score += 1
    if no2 is not None and no2 > 200: score += 1

    if score == 0:
        return "Good"
    elif score == 1:
        return "Moderate"
    else:
        return "Unhealthy"
    
# Function to generate random air quality data
def generate_air_quality_data(sensor_id=3):
    pm2_5 = round(random.uniform(0, 250), 2)
    pm10 = round(random.uniform(0, 500), 2)
    so2 = round(random.uniform(0, 300), 2)
    no2 = round(random.uniform(0, 500), 2) if random.random() > 0.2 else None

    health_environment = classify_health_environment(pm2_5, pm10, so2, no2)

    return {
        "sensor_id": sensor_id,
        "timestamp": datetime.now().isoformat(),
        "pm2_5": pm2_5,
        "pm10": pm10,
        "so2": so2,
        "no2": no2,
        "health_environment": health_environment.lower()
    }

# Impute only no2 values using mean, median, mode or regression
def impute_missing_values(df, strategy='mean'):
    if strategy == 'mean':
        df['no2'] = df['no2'].fillna(df['no2'].mean()).round(2)
    elif strategy == 'median':
         df['no2'] = df['no2'].fillna(df['no2'].median()).round(2)
    elif strategy == 'mode':
        df['no2'] = df['no2'].fillna(df['no2'].mode()).round(2)
    elif strategy == 'regression':
        # Only impute no2 values using so2 as predictor
        hum_train = df.dropna(subset=['no2'])
        model = LinearRegression()
        model.fit(hum_train[['so2']], hum_train['no2'])
        hum_missing = df[df['no2'].isnull()]
        df.loc[df['no2'].isnull(), 'no2'] = model.predict(hum_missing[['so2']]).round(2)
    return df

# Function to save data as XML
def save_air_quality_xml(filename, data):
    root = ET.Element("AirQualityReadings")
    for reading in data:
        reading_elem = ET.SubElement(root, "Reading")
        for key, value in reading.items():
            elem = ET.SubElement(reading_elem, key)
            elem.text = str(value)
    # Convert to string and pretty-print
    rough_string = ET.tostring(root, 'utf-8')
    reparsed = minidom.parseString(rough_string)
    pretty_xml = reparsed.toprettyxml(indent="  ")

    # Save to file
    filepath = os.path.join(output_dir, filename)
    with open(filepath, "w", encoding="utf-8") as f:
        f.write(pretty_xml)

    print(f"Saved Air Quality XML: {filepath}")

# User input for number of times to run
num_iterations = int(input("Enter number of air quality readings to generate: "))

# Generate multiple batches of air quality data
readings = []
for i in range(num_iterations):
    air_quality_data = generate_air_quality_data()
    print(air_quality_data)
    readings.append(air_quality_data)
    time.sleep(0)  # Simulate real-time data generation

    # Add a duplicate at every 3rd reading
    if i % 3 == 0 and i != 0:
        readings.append(air_quality_data)
        print(air_quality_data)

# Create DataFrame
df = pd.DataFrame(readings)

# Save raw data (with duplicates)
save_air_quality_xml("air_quality_readings_errors.xml", df.to_dict(orient='records'))

# Remove duplicated rows
df = df.drop_duplicates()

# Impute missing no2 values 
df = impute_missing_values(df, strategy="mean")

# Save cleaned data (without duplicates)
save_air_quality_xml("air_quality_readings.xml", df.to_dict(orient='records'))

df.to_csv("air_quality_reading.csv", index=False)

data = pd.read_csv('air_quality_readings.csv')

print("Total number of samples: ", len(data))

print("Number of samples for each category: ")
print(data['health_environment'].value_counts())
# Out:
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 77.44, 'pm10': 34.01, 'so2': 198.4, 'no2': 41.89, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 123.43, 'pm10': 235.15, 'so2': 20.73, 'no2': 416.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 140.77, 'pm10': 293.03, 'so2': 19.01, 'no2': 212.67, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 8.11, 'pm10': 461.04, 'so2': 154.17, 'no2': 186.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 8.11, 'pm10': 461.04, 'so2': 154.17, 'no2': 186.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 60.34, 'pm10': 255.77, 'so2': 254.3, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 101.43, 'pm10': 133.36, 'so2': 50.07, 'no2': 267.11, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 189.68, 'pm10': 266.48, 'so2': 198.02, 'no2': 54.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 189.68, 'pm10': 266.48, 'so2': 198.02, 'no2': 54.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 150.41, 'pm10': 102.21, 'so2': 75.17, 'no2': 32.41, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 76.22, 'pm10': 468.28, 'so2': 83.41, 'no2': 416.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 239.83, 'pm10': 250.21, 'so2': 138.27, 'no2': 262.9, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 239.83, 'pm10': 250.21, 'so2': 138.27, 'no2': 262.9, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 52.28, 'pm10': 226.4, 'so2': 283.83, 'no2': 494.4, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 194.18, 'pm10': 50.09, 'so2': 226.48, 'no2': 469.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 236.04, 'pm10': 281.84, 'so2': 75.97, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 236.04, 'pm10': 281.84, 'so2': 75.97, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 120.43, 'pm10': 2.12, 'so2': 269.64, 'no2': 348.49, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 18.93, 'pm10': 160.44, 'so2': 172.8, 'no2': 191.1, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 36.7, 'pm10': 191.25, 'so2': 161.01, 'no2': 449.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 36.7, 'pm10': 191.25, 'so2': 161.01, 'no2': 449.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 19.06, 'pm10': 161.43, 'so2': 80.19, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 198.66, 'pm10': 262.15, 'so2': 295.03, 'no2': 71.51, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 116.28, 'pm10': 291.5, 'so2': 184.09, 'no2': 8.29, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 116.28, 'pm10': 291.5, 'so2': 184.09, 'no2': 8.29, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 114.43, 'pm10': 22.49, 'so2': 64.68, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 171.28, 'pm10': 47.95, 'so2': 26.64, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 149.59, 'pm10': 277.85, 'so2': 203.49, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 149.59, 'pm10': 277.85, 'so2': 203.49, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 165.39, 'pm10': 379.0, 'so2': 173.31, 'no2': 25.16, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 99.03, 'pm10': 480.61, 'so2': 297.62, 'no2': 490.54, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 86.17, 'pm10': 444.94, 'so2': 118.12, 'no2': 53.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.835276', 'pm2_5': 86.17, 'pm10': 444.94, 'so2': 118.12, 'no2': 53.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 229.16, 'pm10': 289.18, 'so2': 218.13, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 111.28, 'pm10': 402.87, 'so2': 66.6, 'no2': 407.91, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 150.39, 'pm10': 371.99, 'so2': 126.44, 'no2': 196.63, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 150.39, 'pm10': 371.99, 'so2': 126.44, 'no2': 196.63, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 16.2, 'pm10': 53.69, 'so2': 266.06, 'no2': 173.31, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 103.7, 'pm10': 375.04, 'so2': 58.13, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 38.15, 'pm10': 207.8, 'so2': 92.8, 'no2': 61.62, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 38.15, 'pm10': 207.8, 'so2': 92.8, 'no2': 61.62, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 17.74, 'pm10': 462.88, 'so2': 139.89, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 160.83, 'pm10': 64.87, 'so2': 264.78, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 101.52, 'pm10': 388.27, 'so2': 28.5, 'no2': 386.38, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 101.52, 'pm10': 388.27, 'so2': 28.5, 'no2': 386.38, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 236.42, 'pm10': 430.63, 'so2': 142.53, 'no2': 258.54, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 111.78, 'pm10': 118.06, 'so2': 99.61, 'no2': 346.97, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 98.87, 'pm10': 378.41, 'so2': 79.89, 'no2': 251.52, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 98.87, 'pm10': 378.41, 'so2': 79.89, 'no2': 251.52, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 91.59, 'pm10': 215.2, 'so2': 125.26, 'no2': 15.63, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 127.89, 'pm10': 477.14, 'so2': 219.53, 'no2': 247.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 88.95, 'pm10': 288.19, 'so2': 122.82, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 88.95, 'pm10': 288.19, 'so2': 122.82, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 29.0, 'pm10': 399.86, 'so2': 115.02, 'no2': 270.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 180.07, 'pm10': 365.0, 'so2': 73.49, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 246.39, 'pm10': 317.09, 'so2': 282.73, 'no2': 372.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 246.39, 'pm10': 317.09, 'so2': 282.73, 'no2': 372.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 164.03, 'pm10': 17.66, 'so2': 134.25, 'no2': 359.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 68.05, 'pm10': 452.41, 'so2': 139.71, 'no2': 468.96, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 211.24, 'pm10': 396.13, 'so2': 137.96, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 211.24, 'pm10': 396.13, 'so2': 137.96, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 196.3, 'pm10': 110.68, 'so2': 254.98, 'no2': 205.02, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 21.83, 'pm10': 174.83, 'so2': 46.43, 'no2': 308.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 197.71, 'pm10': 417.07, 'so2': 50.93, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 197.71, 'pm10': 417.07, 'so2': 50.93, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 45.97, 'pm10': 265.7, 'so2': 282.44, 'no2': 49.11, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 205.75, 'pm10': 0.51, 'so2': 257.78, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 52.74, 'pm10': 145.72, 'so2': 172.15, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 52.74, 'pm10': 145.72, 'so2': 172.15, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 152.61, 'pm10': 253.01, 'so2': 205.02, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 161.91, 'pm10': 202.36, 'so2': 159.19, 'no2': 355.42, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 230.74, 'pm10': 370.06, 'so2': 218.92, 'no2': 302.08, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 230.74, 'pm10': 370.06, 'so2': 218.92, 'no2': 302.08, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 86.95, 'pm10': 31.8, 'so2': 225.07, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 187.74, 'pm10': 80.52, 'so2': 82.95, 'no2': 125.65, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 207.5, 'pm10': 286.83, 'so2': 108.94, 'no2': 84.3, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 207.5, 'pm10': 286.83, 'so2': 108.94, 'no2': 84.3, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 176.01, 'pm10': 158.55, 'so2': 225.14, 'no2': 287.48, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 115.09, 'pm10': 47.59, 'so2': 80.11, 'no2': 269.87, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 41.43, 'pm10': 426.62, 'so2': 244.27, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 41.43, 'pm10': 426.62, 'so2': 244.27, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 83.56, 'pm10': 353.78, 'so2': 33.5, 'no2': 277.38, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 11.13, 'pm10': 20.01, 'so2': 253.23, 'no2': 203.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 2.24, 'pm10': 376.77, 'so2': 92.7, 'no2': 343.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 2.24, 'pm10': 376.77, 'so2': 92.7, 'no2': 343.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 34.46, 'pm10': 209.37, 'so2': 30.33, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 54.45, 'pm10': 54.71, 'so2': 144.47, 'no2': 328.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 27.7, 'pm10': 376.21, 'so2': 76.61, 'no2': 204.59, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 27.7, 'pm10': 376.21, 'so2': 76.61, 'no2': 204.59, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 71.95, 'pm10': 93.05, 'so2': 243.64, 'no2': 91.55, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 26.72, 'pm10': 113.36, 'so2': 189.97, 'no2': 430.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 190.34, 'pm10': 359.89, 'so2': 134.62, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 190.34, 'pm10': 359.89, 'so2': 134.62, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 82.84, 'pm10': 31.16, 'so2': 9.84, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 180.74, 'pm10': 429.86, 'so2': 284.2, 'no2': 417.78, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 173.66, 'pm10': 400.01, 'so2': 143.62, 'no2': 53.91, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 173.66, 'pm10': 400.01, 'so2': 143.62, 'no2': 53.91, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 245.51, 'pm10': 487.28, 'so2': 27.96, 'no2': 79.75, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.836276', 'pm2_5': 248.78, 'pm10': 4.82, 'so2': 32.33, 'no2': 438.56, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 53.24, 'pm10': 213.64, 'so2': 34.83, 'no2': 171.97, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 53.24, 'pm10': 213.64, 'so2': 34.83, 'no2': 171.97, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 131.66, 'pm10': 91.89, 'so2': 84.16, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 137.21, 'pm10': 358.82, 'so2': 111.48, 'no2': 311.53, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 46.4, 'pm10': 408.82, 'so2': 212.54, 'no2': 103.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 46.4, 'pm10': 408.82, 'so2': 212.54, 'no2': 103.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 138.11, 'pm10': 320.32, 'so2': 198.39, 'no2': 12.96, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 240.5, 'pm10': 130.28, 'so2': 4.43, 'no2': 147.82, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 71.61, 'pm10': 324.15, 'so2': 291.33, 'no2': 433.77, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 71.61, 'pm10': 324.15, 'so2': 291.33, 'no2': 433.77, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 216.95, 'pm10': 24.75, 'so2': 104.54, 'no2': 82.28, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 111.51, 'pm10': 340.91, 'so2': 3.65, 'no2': 316.41, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 179.51, 'pm10': 93.99, 'so2': 110.58, 'no2': 240.51, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 179.51, 'pm10': 93.99, 'so2': 110.58, 'no2': 240.51, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 198.61, 'pm10': 468.52, 'so2': 276.97, 'no2': 257.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 224.3, 'pm10': 119.72, 'so2': 166.01, 'no2': 443.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 110.21, 'pm10': 188.14, 'so2': 19.6, 'no2': 248.67, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 110.21, 'pm10': 188.14, 'so2': 19.6, 'no2': 248.67, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 53.62, 'pm10': 462.53, 'so2': 82.84, 'no2': 301.73, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 79.02, 'pm10': 340.87, 'so2': 246.97, 'no2': 216.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 56.29, 'pm10': 113.95, 'so2': 139.84, 'no2': 328.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 56.29, 'pm10': 113.95, 'so2': 139.84, 'no2': 328.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 197.28, 'pm10': 110.82, 'so2': 241.77, 'no2': 436.71, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 214.58, 'pm10': 330.55, 'so2': 195.05, 'no2': 230.06, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 111.8, 'pm10': 100.85, 'so2': 100.39, 'no2': 291.39, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 111.8, 'pm10': 100.85, 'so2': 100.39, 'no2': 291.39, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 46.54, 'pm10': 98.53, 'so2': 127.8, 'no2': 386.37, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 28.44, 'pm10': 442.58, 'so2': 25.99, 'no2': 234.12, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 11.46, 'pm10': 32.05, 'so2': 92.3, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 11.46, 'pm10': 32.05, 'so2': 92.3, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 27.13, 'pm10': 412.32, 'so2': 43.91, 'no2': 76.16, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 8.45, 'pm10': 258.23, 'so2': 218.18, 'no2': 298.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 171.35, 'pm10': 71.65, 'so2': 185.75, 'no2': 448.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 171.35, 'pm10': 71.65, 'so2': 185.75, 'no2': 448.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 144.96, 'pm10': 77.01, 'so2': 49.81, 'no2': 370.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 21.38, 'pm10': 24.26, 'so2': 136.22, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 57.3, 'pm10': 95.12, 'so2': 45.6, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 57.3, 'pm10': 95.12, 'so2': 45.6, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 95.19, 'pm10': 130.38, 'so2': 265.22, 'no2': 274.2, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 209.56, 'pm10': 349.89, 'so2': 152.66, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 210.34, 'pm10': 71.05, 'so2': 42.05, 'no2': 451.87, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 210.34, 'pm10': 71.05, 'so2': 42.05, 'no2': 451.87, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 223.23, 'pm10': 468.72, 'so2': 20.26, 'no2': 292.74, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 101.4, 'pm10': 295.21, 'so2': 70.85, 'no2': 108.88, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 243.81, 'pm10': 136.52, 'so2': 30.63, 'no2': 400.46, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 243.81, 'pm10': 136.52, 'so2': 30.63, 'no2': 400.46, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 4.59, 'pm10': 112.29, 'so2': 167.11, 'no2': 307.14, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 186.19, 'pm10': 462.96, 'so2': 237.97, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 26.82, 'pm10': 4.66, 'so2': 177.7, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 26.82, 'pm10': 4.66, 'so2': 177.7, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 98.01, 'pm10': 382.47, 'so2': 256.75, 'no2': 10.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 173.85, 'pm10': 17.65, 'so2': 37.73, 'no2': 321.49, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 159.96, 'pm10': 24.52, 'so2': 40.56, 'no2': 114.1, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 159.96, 'pm10': 24.52, 'so2': 40.56, 'no2': 114.1, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 200.69, 'pm10': 476.88, 'so2': 219.79, 'no2': 487.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 242.24, 'pm10': 248.83, 'so2': 53.8, 'no2': 240.56, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 53.25, 'pm10': 458.97, 'so2': 275.53, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 53.25, 'pm10': 458.97, 'so2': 275.53, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 9.08, 'pm10': 334.61, 'so2': 228.17, 'no2': 8.41, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 110.49, 'pm10': 287.21, 'so2': 147.26, 'no2': 324.02, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 112.83, 'pm10': 478.23, 'so2': 261.9, 'no2': 179.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 112.83, 'pm10': 478.23, 'so2': 261.9, 'no2': 179.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 46.68, 'pm10': 339.05, 'so2': 136.8, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 25.71, 'pm10': 55.67, 'so2': 273.12, 'no2': 479.24, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 207.07, 'pm10': 29.45, 'so2': 43.83, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 207.07, 'pm10': 29.45, 'so2': 43.83, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 191.2, 'pm10': 258.66, 'so2': 263.94, 'no2': 82.76, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 188.42, 'pm10': 482.5, 'so2': 142.48, 'no2': 339.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 83.93, 'pm10': 202.53, 'so2': 213.37, 'no2': 0.94, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 83.93, 'pm10': 202.53, 'so2': 213.37, 'no2': 0.94, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 178.09, 'pm10': 34.58, 'so2': 176.83, 'no2': 134.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 86.56, 'pm10': 92.71, 'so2': 52.08, 'no2': 216.25, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 136.1, 'pm10': 444.84, 'so2': 39.18, 'no2': 460.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 136.1, 'pm10': 444.84, 'so2': 39.18, 'no2': 460.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 100.7, 'pm10': 387.64, 'so2': 2.75, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 87.38, 'pm10': 360.4, 'so2': 293.15, 'no2': 432.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 86.07, 'pm10': 488.18, 'so2': 9.55, 'no2': 129.66, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 86.07, 'pm10': 488.18, 'so2': 9.55, 'no2': 129.66, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 237.4, 'pm10': 390.96, 'so2': 151.52, 'no2': 203.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 231.91, 'pm10': 130.27, 'so2': 141.94, 'no2': 344.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 219.77, 'pm10': 361.65, 'so2': 158.53, 'no2': 420.74, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 219.77, 'pm10': 361.65, 'so2': 158.53, 'no2': 420.74, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 82.52, 'pm10': 144.99, 'so2': 114.52, 'no2': 335.48, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 55.35, 'pm10': 354.09, 'so2': 26.86, 'no2': 37.53, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 232.05, 'pm10': 214.01, 'so2': 18.52, 'no2': 375.17, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 232.05, 'pm10': 214.01, 'so2': 18.52, 'no2': 375.17, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.837279', 'pm2_5': 232.88, 'pm10': 307.95, 'so2': 124.95, 'no2': 248.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 88.33, 'pm10': 381.68, 'so2': 221.01, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 180.01, 'pm10': 357.12, 'so2': 169.51, 'no2': 231.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 180.01, 'pm10': 357.12, 'so2': 169.51, 'no2': 231.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 214.81, 'pm10': 345.01, 'so2': 249.68, 'no2': 92.05, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 201.18, 'pm10': 44.57, 'so2': 118.75, 'no2': 478.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 196.04, 'pm10': 229.48, 'so2': 125.04, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 196.04, 'pm10': 229.48, 'so2': 125.04, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 174.25, 'pm10': 168.83, 'so2': 69.35, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 236.59, 'pm10': 373.95, 'so2': 167.69, 'no2': 32.03, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 216.38, 'pm10': 129.02, 'so2': 115.24, 'no2': 384.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 216.38, 'pm10': 129.02, 'so2': 115.24, 'no2': 384.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 58.24, 'pm10': 131.28, 'so2': 82.93, 'no2': 338.48, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 88.48, 'pm10': 346.53, 'so2': 292.18, 'no2': 232.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 104.8, 'pm10': 414.09, 'so2': 175.15, 'no2': 381.2, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 104.8, 'pm10': 414.09, 'so2': 175.15, 'no2': 381.2, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 138.33, 'pm10': 470.17, 'so2': 82.6, 'no2': 58.49, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 248.8, 'pm10': 306.89, 'so2': 74.36, 'no2': 370.61, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 138.71, 'pm10': 396.67, 'so2': 262.32, 'no2': 303.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 138.71, 'pm10': 396.67, 'so2': 262.32, 'no2': 303.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 144.26, 'pm10': 399.33, 'so2': 168.47, 'no2': 361.07, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 171.63, 'pm10': 435.91, 'so2': 170.08, 'no2': 172.87, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 43.81, 'pm10': 230.04, 'so2': 47.08, 'no2': 416.99, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 43.81, 'pm10': 230.04, 'so2': 47.08, 'no2': 416.99, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 42.62, 'pm10': 203.92, 'so2': 89.37, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 118.09, 'pm10': 438.16, 'so2': 170.77, 'no2': 60.86, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 142.01, 'pm10': 288.19, 'so2': 23.31, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 142.01, 'pm10': 288.19, 'so2': 23.31, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 82.29, 'pm10': 96.13, 'so2': 115.94, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 165.91, 'pm10': 452.88, 'so2': 95.49, 'no2': 258.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 232.73, 'pm10': 282.35, 'so2': 157.74, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 232.73, 'pm10': 282.35, 'so2': 157.74, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 81.58, 'pm10': 49.44, 'so2': 225.03, 'no2': 79.19, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 89.99, 'pm10': 58.86, 'so2': 191.84, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 119.95, 'pm10': 322.68, 'so2': 129.21, 'no2': 282.9, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 119.95, 'pm10': 322.68, 'so2': 129.21, 'no2': 282.9, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 53.84, 'pm10': 243.31, 'so2': 34.45, 'no2': 465.6, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 175.5, 'pm10': 422.03, 'so2': 106.77, 'no2': 29.16, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 215.59, 'pm10': 467.85, 'so2': 297.63, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 215.59, 'pm10': 467.85, 'so2': 297.63, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 168.19, 'pm10': 215.26, 'so2': 171.45, 'no2': 275.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 117.41, 'pm10': 349.81, 'so2': 274.15, 'no2': 44.78, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 158.94, 'pm10': 327.77, 'so2': 181.79, 'no2': 438.55, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 158.94, 'pm10': 327.77, 'so2': 181.79, 'no2': 438.55, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 168.31, 'pm10': 206.58, 'so2': 7.01, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 30.16, 'pm10': 84.71, 'so2': 20.77, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 18.86, 'pm10': 140.55, 'so2': 243.02, 'no2': 149.41, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 18.86, 'pm10': 140.55, 'so2': 243.02, 'no2': 149.41, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 19.26, 'pm10': 178.29, 'so2': 243.29, 'no2': 333.45, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 138.61, 'pm10': 24.35, 'so2': 221.0, 'no2': 359.83, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 120.01, 'pm10': 124.4, 'so2': 79.49, 'no2': 311.62, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 120.01, 'pm10': 124.4, 'so2': 79.49, 'no2': 311.62, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 166.2, 'pm10': 485.06, 'so2': 168.73, 'no2': 203.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 12.75, 'pm10': 336.44, 'so2': 6.03, 'no2': 335.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 217.5, 'pm10': 108.7, 'so2': 6.93, 'no2': 321.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 217.5, 'pm10': 108.7, 'so2': 6.93, 'no2': 321.66, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 107.62, 'pm10': 215.12, 'so2': 209.38, 'no2': 191.15, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 68.91, 'pm10': 2.08, 'so2': 20.7, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 112.16, 'pm10': 231.91, 'so2': 83.02, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 112.16, 'pm10': 231.91, 'so2': 83.02, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 184.8, 'pm10': 375.91, 'so2': 271.34, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 8.66, 'pm10': 242.82, 'so2': 11.71, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 210.99, 'pm10': 99.0, 'so2': 295.41, 'no2': 357.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 210.99, 'pm10': 99.0, 'so2': 295.41, 'no2': 357.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 152.07, 'pm10': 21.76, 'so2': 266.21, 'no2': 435.92, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 83.54, 'pm10': 276.56, 'so2': 147.37, 'no2': 391.99, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 207.88, 'pm10': 466.6, 'so2': 24.02, 'no2': 22.46, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 207.88, 'pm10': 466.6, 'so2': 24.02, 'no2': 22.46, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 249.29, 'pm10': 295.22, 'so2': 203.32, 'no2': 294.01, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 47.67, 'pm10': 76.79, 'so2': 214.86, 'no2': 317.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 14.65, 'pm10': 280.67, 'so2': 191.74, 'no2': 53.12, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 14.65, 'pm10': 280.67, 'so2': 191.74, 'no2': 53.12, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 110.06, 'pm10': 143.29, 'so2': 66.7, 'no2': 354.51, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 176.36, 'pm10': 340.93, 'so2': 139.0, 'no2': 83.91, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 131.56, 'pm10': 443.23, 'so2': 90.27, 'no2': 48.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 131.56, 'pm10': 443.23, 'so2': 90.27, 'no2': 48.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 126.87, 'pm10': 326.74, 'so2': 116.12, 'no2': 447.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 44.6, 'pm10': 277.74, 'so2': 282.31, 'no2': 201.84, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 167.12, 'pm10': 392.66, 'so2': 155.92, 'no2': 248.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 167.12, 'pm10': 392.66, 'so2': 155.92, 'no2': 248.89, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 27.24, 'pm10': 210.95, 'so2': 65.79, 'no2': 376.11, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 13.22, 'pm10': 232.05, 'so2': 159.7, 'no2': 151.75, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 139.86, 'pm10': 294.4, 'so2': 100.04, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.838283', 'pm2_5': 139.86, 'pm10': 294.4, 'so2': 100.04, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 133.25, 'pm10': 380.65, 'so2': 228.12, 'no2': 428.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 107.8, 'pm10': 196.85, 'so2': 17.95, 'no2': 160.22, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 236.66, 'pm10': 499.73, 'so2': 221.83, 'no2': 235.48, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 236.66, 'pm10': 499.73, 'so2': 221.83, 'no2': 235.48, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 74.05, 'pm10': 68.91, 'so2': 70.17, 'no2': 192.09, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 208.98, 'pm10': 279.47, 'so2': 292.91, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 197.59, 'pm10': 161.79, 'so2': 36.41, 'no2': 412.95, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 197.59, 'pm10': 161.79, 'so2': 36.41, 'no2': 412.95, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 142.48, 'pm10': 355.34, 'so2': 59.45, 'no2': 198.08, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 101.07, 'pm10': 354.6, 'so2': 104.4, 'no2': 332.68, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 121.41, 'pm10': 271.84, 'so2': 202.73, 'no2': 238.99, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 121.41, 'pm10': 271.84, 'so2': 202.73, 'no2': 238.99, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 58.54, 'pm10': 39.86, 'so2': 172.27, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 205.4, 'pm10': 368.2, 'so2': 43.24, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 152.11, 'pm10': 278.72, 'so2': 68.06, 'no2': 451.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 152.11, 'pm10': 278.72, 'so2': 68.06, 'no2': 451.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 173.57, 'pm10': 86.64, 'so2': 52.09, 'no2': 19.9, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 74.82, 'pm10': 231.4, 'so2': 8.48, 'no2': 6.11, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 177.12, 'pm10': 241.47, 'so2': 36.5, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 177.12, 'pm10': 241.47, 'so2': 36.5, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 95.85, 'pm10': 325.61, 'so2': 266.28, 'no2': 205.48, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 43.94, 'pm10': 50.93, 'so2': 207.84, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 167.43, 'pm10': 398.72, 'so2': 269.65, 'no2': 317.22, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 167.43, 'pm10': 398.72, 'so2': 269.65, 'no2': 317.22, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 193.01, 'pm10': 141.15, 'so2': 194.01, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 111.15, 'pm10': 36.71, 'so2': 50.84, 'no2': 363.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 51.94, 'pm10': 29.15, 'so2': 73.76, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 51.94, 'pm10': 29.15, 'so2': 73.76, 'no2': None, 'health_environment': 'good'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 52.49, 'pm10': 410.65, 'so2': 269.99, 'no2': 338.11, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 181.91, 'pm10': 325.08, 'so2': 171.14, 'no2': 330.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 13.54, 'pm10': 2.22, 'so2': 98.87, 'no2': 395.06, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 13.54, 'pm10': 2.22, 'so2': 98.87, 'no2': 395.06, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 205.14, 'pm10': 140.24, 'so2': 70.19, 'no2': 204.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 180.76, 'pm10': 44.29, 'so2': 18.74, 'no2': 285.33, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 197.7, 'pm10': 21.4, 'so2': 267.8, 'no2': 66.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 197.7, 'pm10': 21.4, 'so2': 267.8, 'no2': 66.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 121.84, 'pm10': 286.22, 'so2': 268.59, 'no2': 291.35, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 219.02, 'pm10': 172.21, 'so2': 184.58, 'no2': 292.29, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:15.839276', 'pm2_5': 50.75, 'pm10': 397.32, 'so2': 145.63, 'no2': 75.12, 'health_environment': 'unhealthy'}
# ...
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.827671', 'pm2_5': 220.66, 'pm10': 427.45, 'so2': 269.65, 'no2': 253.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.828671', 'pm2_5': 191.16, 'pm10': 308.02, 'so2': 106.04, 'no2': 103.17, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.829671', 'pm2_5': 74.67, 'pm10': 229.04, 'so2': 147.91, 'no2': 497.4, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.829671', 'pm2_5': 74.67, 'pm10': 229.04, 'so2': 147.91, 'no2': 497.4, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.831665', 'pm2_5': 32.06, 'pm10': 462.38, 'so2': 51.68, 'no2': 137.8, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.833680', 'pm2_5': 221.6, 'pm10': 10.69, 'so2': 107.63, 'no2': 10.8, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.834672', 'pm2_5': 42.04, 'pm10': 166.44, 'so2': 179.94, 'no2': 474.08, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.834672', 'pm2_5': 42.04, 'pm10': 166.44, 'so2': 179.94, 'no2': 474.08, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.836671', 'pm2_5': 146.07, 'pm10': 436.22, 'so2': 111.21, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.837671', 'pm2_5': 90.55, 'pm10': 420.33, 'so2': 130.82, 'no2': 252.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.838671', 'pm2_5': 58.66, 'pm10': 253.62, 'so2': 145.78, 'no2': 262.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.838671', 'pm2_5': 58.66, 'pm10': 253.62, 'so2': 145.78, 'no2': 262.25, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.840671', 'pm2_5': 237.2, 'pm10': 130.21, 'so2': 9.08, 'no2': 134.24, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.841671', 'pm2_5': 108.69, 'pm10': 446.06, 'so2': 48.7, 'no2': 291.48, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.842671', 'pm2_5': 90.95, 'pm10': 131.86, 'so2': 172.76, 'no2': 494.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.842671', 'pm2_5': 90.95, 'pm10': 131.86, 'so2': 172.76, 'no2': 494.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.844671', 'pm2_5': 150.66, 'pm10': 238.8, 'so2': 221.95, 'no2': 402.73, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.845670', 'pm2_5': 124.67, 'pm10': 183.85, 'so2': 129.64, 'no2': 237.34, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.846671', 'pm2_5': 203.92, 'pm10': 478.93, 'so2': 129.36, 'no2': 14.52, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.846671', 'pm2_5': 203.92, 'pm10': 478.93, 'so2': 129.36, 'no2': 14.52, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.849671', 'pm2_5': 124.25, 'pm10': 221.22, 'so2': 169.6, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.851671', 'pm2_5': 125.93, 'pm10': 299.6, 'so2': 141.66, 'no2': 207.61, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.852672', 'pm2_5': 120.66, 'pm10': 208.31, 'so2': 224.87, 'no2': 483.65, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.852672', 'pm2_5': 120.66, 'pm10': 208.31, 'so2': 224.87, 'no2': 483.65, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.854671', 'pm2_5': 12.97, 'pm10': 182.57, 'so2': 232.66, 'no2': 403.09, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.855675', 'pm2_5': 52.09, 'pm10': 434.97, 'so2': 129.42, 'no2': 487.62, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.856672', 'pm2_5': 62.59, 'pm10': 469.69, 'so2': 264.15, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.856672', 'pm2_5': 62.59, 'pm10': 469.69, 'so2': 264.15, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.858671', 'pm2_5': 245.59, 'pm10': 256.94, 'so2': 265.57, 'no2': 366.36, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.859671', 'pm2_5': 113.34, 'pm10': 334.7, 'so2': 1.0, 'no2': 408.21, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.860671', 'pm2_5': 222.82, 'pm10': 478.97, 'so2': 102.33, 'no2': 113.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.860671', 'pm2_5': 222.82, 'pm10': 478.97, 'so2': 102.33, 'no2': 113.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.862671', 'pm2_5': 115.95, 'pm10': 86.38, 'so2': 197.56, 'no2': 256.05, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.863671', 'pm2_5': 234.15, 'pm10': 289.47, 'so2': 179.34, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.864671', 'pm2_5': 41.65, 'pm10': 493.7, 'so2': 298.98, 'no2': 463.24, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.864671', 'pm2_5': 41.65, 'pm10': 493.7, 'so2': 298.98, 'no2': 463.24, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.867672', 'pm2_5': 15.38, 'pm10': 211.13, 'so2': 289.28, 'no2': 414.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.868672', 'pm2_5': 68.96, 'pm10': 482.85, 'so2': 151.73, 'no2': 191.59, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.869672', 'pm2_5': 36.1, 'pm10': 15.64, 'so2': 189.36, 'no2': 431.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.869672', 'pm2_5': 36.1, 'pm10': 15.64, 'so2': 189.36, 'no2': 431.31, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.872665', 'pm2_5': 138.12, 'pm10': 328.66, 'so2': 231.47, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.873665', 'pm2_5': 98.88, 'pm10': 136.72, 'so2': 101.85, 'no2': 81.59, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.873665', 'pm2_5': 163.55, 'pm10': 237.5, 'so2': 131.46, 'no2': 424.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.873665', 'pm2_5': 163.55, 'pm10': 237.5, 'so2': 131.46, 'no2': 424.04, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.875664', 'pm2_5': 189.99, 'pm10': 414.65, 'so2': 267.17, 'no2': 118.41, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.876665', 'pm2_5': 142.71, 'pm10': 385.96, 'so2': 50.2, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.877664', 'pm2_5': 93.63, 'pm10': 414.69, 'so2': 112.51, 'no2': 170.55, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.877664', 'pm2_5': 93.63, 'pm10': 414.69, 'so2': 112.51, 'no2': 170.55, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.879664', 'pm2_5': 179.17, 'pm10': 212.73, 'so2': 260.62, 'no2': 468.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.880665', 'pm2_5': 161.58, 'pm10': 433.48, 'so2': 299.74, 'no2': 235.98, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.882666', 'pm2_5': 23.71, 'pm10': 417.88, 'so2': 245.51, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.882666', 'pm2_5': 23.71, 'pm10': 417.88, 'so2': 245.51, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.884723', 'pm2_5': 173.02, 'pm10': 411.92, 'so2': 113.05, 'no2': 10.02, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.885741', 'pm2_5': 181.92, 'pm10': 194.99, 'so2': 55.98, 'no2': 232.39, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.886666', 'pm2_5': 24.64, 'pm10': 144.21, 'so2': 281.24, 'no2': 12.06, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.886666', 'pm2_5': 24.64, 'pm10': 144.21, 'so2': 281.24, 'no2': 12.06, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.888667', 'pm2_5': 78.75, 'pm10': 475.89, 'so2': 102.04, 'no2': 394.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.889667', 'pm2_5': 244.99, 'pm10': 268.56, 'so2': 65.43, 'no2': 64.4, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.890666', 'pm2_5': 70.76, 'pm10': 133.1, 'so2': 157.42, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.890666', 'pm2_5': 70.76, 'pm10': 133.1, 'so2': 157.42, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.892667', 'pm2_5': 146.18, 'pm10': 475.62, 'so2': 78.19, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.893667', 'pm2_5': 90.35, 'pm10': 51.14, 'so2': 55.77, 'no2': 237.7, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.894667', 'pm2_5': 227.2, 'pm10': 107.19, 'so2': 122.51, 'no2': 392.8, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.894667', 'pm2_5': 227.2, 'pm10': 107.19, 'so2': 122.51, 'no2': 392.8, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.896666', 'pm2_5': 43.84, 'pm10': 373.55, 'so2': 164.26, 'no2': 328.49, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.897667', 'pm2_5': 237.56, 'pm10': 50.77, 'so2': 29.38, 'no2': 262.82, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.899666', 'pm2_5': 149.2, 'pm10': 159.47, 'so2': 276.77, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.899666', 'pm2_5': 149.2, 'pm10': 159.47, 'so2': 276.77, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.901743', 'pm2_5': 92.35, 'pm10': 60.83, 'so2': 109.5, 'no2': 277.28, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.902739', 'pm2_5': 63.18, 'pm10': 53.54, 'so2': 157.01, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.903742', 'pm2_5': 56.86, 'pm10': 320.4, 'so2': 50.22, 'no2': 333.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.903742', 'pm2_5': 56.86, 'pm10': 320.4, 'so2': 50.22, 'no2': 333.0, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.905740', 'pm2_5': 236.8, 'pm10': 200.68, 'so2': 75.95, 'no2': 236.61, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.906738', 'pm2_5': 4.71, 'pm10': 267.28, 'so2': 282.22, 'no2': 298.41, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.907741', 'pm2_5': 72.0, 'pm10': 305.89, 'so2': 206.08, 'no2': 85.52, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.907741', 'pm2_5': 72.0, 'pm10': 305.89, 'so2': 206.08, 'no2': 85.52, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.909736', 'pm2_5': 186.24, 'pm10': 189.53, 'so2': 141.1, 'no2': 206.45, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.910743', 'pm2_5': 109.5, 'pm10': 296.45, 'so2': 112.54, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.911741', 'pm2_5': 193.93, 'pm10': 65.85, 'so2': 18.36, 'no2': 215.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.911741', 'pm2_5': 193.93, 'pm10': 65.85, 'so2': 18.36, 'no2': 215.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.914743', 'pm2_5': 158.77, 'pm10': 52.44, 'so2': 43.77, 'no2': None, 'health_environment': 'moderate'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.915668', 'pm2_5': 3.81, 'pm10': 362.6, 'so2': 140.47, 'no2': 408.13, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.916668', 'pm2_5': 228.17, 'pm10': 369.51, 'so2': 203.53, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.916668', 'pm2_5': 228.17, 'pm10': 369.51, 'so2': 203.53, 'no2': None, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.919718', 'pm2_5': 26.21, 'pm10': 304.83, 'so2': 115.9, 'no2': 157.49, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.920678', 'pm2_5': 181.3, 'pm10': 64.09, 'so2': 232.39, 'no2': 354.59, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.921671', 'pm2_5': 157.84, 'pm10': 484.74, 'so2': 270.06, 'no2': 457.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.921671', 'pm2_5': 157.84, 'pm10': 484.74, 'so2': 270.06, 'no2': 457.44, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.923673', 'pm2_5': 105.48, 'pm10': 324.42, 'so2': 221.81, 'no2': 44.48, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.924672', 'pm2_5': 15.84, 'pm10': 419.01, 'so2': 224.85, 'no2': 325.19, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.925671', 'pm2_5': 38.51, 'pm10': 203.47, 'so2': 237.58, 'no2': 349.53, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.925671', 'pm2_5': 38.51, 'pm10': 203.47, 'so2': 237.58, 'no2': 349.53, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.927670', 'pm2_5': 157.37, 'pm10': 342.89, 'so2': 280.84, 'no2': 206.64, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.928671', 'pm2_5': 233.13, 'pm10': 313.6, 'so2': 281.99, 'no2': 334.15, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.929671', 'pm2_5': 103.3, 'pm10': 370.38, 'so2': 270.11, 'no2': 476.67, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.929671', 'pm2_5': 103.3, 'pm10': 370.38, 'so2': 270.11, 'no2': 476.67, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.932666', 'pm2_5': 138.0, 'pm10': 41.98, 'so2': 162.78, 'no2': 352.69, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.934666', 'pm2_5': 110.81, 'pm10': 11.89, 'so2': 292.22, 'no2': 454.27, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.935666', 'pm2_5': 177.79, 'pm10': 173.09, 'so2': 79.54, 'no2': 440.21, 'health_environment': 'unhealthy'}
# {'sensor_id': 3, 'timestamp': '2025-04-08T10:34:22.935666', 'pm2_5': 177.79, 'pm10': 173.09, 'so2': 79.54, 'no2': 440.21, 'health_environment': 'unhealthy'}
# Saved Air Quality XML: sensor_data/xml\air_quality_readings_errors.xml
# Saved Air Quality XML: sensor_data/xml\air_quality_readings.xml
# Total number of samples:  10000
# Number of samples for each category:
# health_environment
# unhealthy    8410
# moderate     1372
# good          218
# Name: count, dtype: int64
